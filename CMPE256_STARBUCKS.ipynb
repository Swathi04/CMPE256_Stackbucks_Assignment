# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathi04/CMPE256_Stackbucks_Assignment/blob/main/CMPE256_STARBUCKS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CMPE 256 Assignment: Starbucks Hot Beverages Cluster Assignment

# %% [markdown]
# ##Necessary Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ##Create an array for the data given

# %%
data = np.array([[1, 5], [1, 7], [2, 6], [2, 9], [3, 3], [3, 6], [3, 8], [3, 9], [4, 5], [4, 8], [5, 4], [5, 7], [6, 9], [7, 2], [7, 3], [7, 9], [8, 1], [8, 7]])

# %% [markdown]
# ##Plot the graph for all the points

# %%
labels = range(1, 12)
plt.figure(figsize=(10, 7))
plt.subplots_adjust(bottom=0.1)
plt.scatter(data[:,0], data[:,1], label='True Positions')

# %% [markdown]
# ##Create Dendograms

# %% [markdown]
# ###For Single Link Clustering

# %%
x
linked = linkage(y=data, method='single')
labelList= range(1, 19)
plt.figure(figsize=(10, 7))
dendrogram(linked,  orientation='top',labels=labelList,distance_sort='descending',show_leaf_counts=True)
plt.show()

# %% [markdown]
# ###For Complete Link Clustering

# %%
linked_complete= linkage(data, 'complete')
labelList= range(1, 19)
plt.figure(figsize=(10, 7))
dendrogram(linked_complete,  orientation='top',labels=labelList,distance_sort='descending',show_leaf_counts=True)
plt.show()

# %% [markdown]
# ###For Average Link Clustering

# %%
linked_average= linkage(data, 'average')
labelList= range(1, 19)
plt.figure(figsize=(10, 7))
dendrogram(linked_complete,  orientation='top',labels=labelList,distance_sort='descending',show_leaf_counts=True)
plt.show()
